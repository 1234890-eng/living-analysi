# %%
import numpy as np
import pandas as pd
import seaborn as sns
data=pd.read_csv(r"costofliving-query-tweets.csv")
data
# Out:
#                         date_time         username  \
# 0       2022-09-09 00:19:49+00:00  Beer_Enjoyer420
# 1       2022-09-09 00:19:48+00:00    MLAIrfanSabir
# 2       2022-09-09 00:19:04+00:00         AFDJnews
# 3       2022-09-09 00:18:51+00:00       LitmusTree
# 4       2022-09-09 00:18:23+00:00      athenastits
# ...                           ...              ...
# 144957  2022-08-20 20:19:10+00:00        MaryTracy
# 144958  2022-08-20 20:18:57+00:00         _Fessial
# 144959  2022-08-20 20:18:47+00:00   billyphillyboi
# 144960  2022-08-20 20:18:23+00:00      AnnaDe_2015
# 144961  2022-08-20 20:17:49+00:00   NzuchiTimesUSA
#
#                         user_location  \
# 0           District of Columbia, USA
# 1         Calgary, Treaty 7 Territory
# 2                           Australia
# 3                      Yah Dads House
# 4       they/them | 18 | uk | leftist
# ...                               ...
# 144957                        England
# ...

# %%
data.shape
# Out:
# (144962, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144962 entries, 0 to 144961
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date_time            144962 non-null  object
#  1   username             144962 non-null  object
#  2   user_location        100422 non-null  object
#  3   user_description     125013 non-null  object
#  4   verified             144962 non-null  bool
#  5   followers_count      144962 non-null  int64
#  6   following_count      144962 non-null  int64
#  7   tweet_like_count     144962 non-null  int64
#  8   tweet_retweet_count  144962 non-null  int64
#  9   tweet_reply_count    144962 non-null  int64
#  10  source               144962 non-null  object
#  11  tweet_text           144962 non-null  object
# dtypes: bool(1), int64(5), object(6)
# memory usage: 12.3+ MB

# %%
data.head()
# Out:
#                    date_time         username                  user_location  \
# 0  2022-09-09 00:19:49+00:00  Beer_Enjoyer420      District of Columbia, USA
# 1  2022-09-09 00:19:48+00:00    MLAIrfanSabir    Calgary, Treaty 7 Territory
# 2  2022-09-09 00:19:04+00:00         AFDJnews                      Australia
# 3  2022-09-09 00:18:51+00:00       LitmusTree                 Yah Dads House
# 4  2022-09-09 00:18:23+00:00      athenastits  they/them | 18 | uk | leftist
#
#                                     user_description  verified  \
# 0  I like news, weather, and sports updates! (And...     False
# 1  The official account of MLA Irfan Sabir, JSS C...      True
# 2  ADFJ is your top Australian farming industry n...     False
# 3  🇹🇼You looked through my profile after you saw ...     False
# 4  if it's not our flag means death it's the old ...     False
#
#    followers_count  following_count  tweet_like_count  tweet_retweet_count  \
# ...

# %%
data.describe()
# Out:
#        followers_count  following_count  tweet_like_count  \
# count     1.449620e+05    144962.000000     144962.000000
# mean      4.474875e+04      1735.925436         16.859922
# std       6.100741e+05      5974.358049        491.427720
# min       0.000000e+00         0.000000          0.000000
# 25%       1.020000e+02       186.000000          0.000000
# 50%       5.570000e+02       632.000000          1.000000
# 75%       2.439750e+03      1800.000000          2.000000
# max       5.422480e+07    638937.000000     105672.000000
#
#        tweet_retweet_count  tweet_reply_count
# count        144962.000000      144962.000000
# mean              4.030380           1.773865
# std             145.847155          34.595891
# min               0.000000           0.000000
# 25%               0.000000           0.000000
# 50%               0.000000           0.000000
# 75%               0.000000           1.000000
# max           44012.000000        5408.000000

# %%
data.tail()
# Out:
#                         date_time        username     user_location  \
# 144957  2022-08-20 20:19:10+00:00       MaryTracy           England
# 144958  2022-08-20 20:18:57+00:00        _Fessial               NaN
# 144959  2022-08-20 20:18:47+00:00  billyphillyboi  Philadelphia, PA
# 144960  2022-08-20 20:18:23+00:00     AnnaDe_2015           London
# 144961  2022-08-20 20:17:49+00:00  NzuchiTimesUSA               USA
#
#                                          user_description  verified  \
# 144957  Writer. Web Designer. Yoga teacher. #Yoga #Spi...     False
# 144958                                       #ModusPonens     False
# 144959  Phillies|Eagles|Sixers|Packers|Sports and Poli...     False
# 144960  Global/European healthcare public affairs prof...     False
# 144961  Nzuchi Times is a fast-growing news site with ...     False
#
#         followers_count  following_count  tweet_like_count  \
# 144957             2277             2298                 1
# ...

# %%
data.columns
# Out:
# Index(['date_time', 'username', 'user_location', 'user_description',
#        'verified', 'followers_count', 'following_count', 'tweet_like_count',
#        'tweet_retweet_count', 'tweet_reply_count', 'source', 'tweet_text'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# date_time                  0
# username                   0
# user_location          44540
# user_description       19949
# verified                   0
# followers_count            0
# following_count            0
# tweet_like_count           0
# tweet_retweet_count        0
# tweet_reply_count          0
# source                     0
# tweet_text                 0
# dtype: int64

# %%
data.isnull()
# Out:
#         date_time  username  user_location  user_description  verified  \
# 0           False     False          False             False     False
# 1           False     False          False             False     False
# 2           False     False          False             False     False
# 3           False     False          False             False     False
# 4           False     False          False             False     False
# ...           ...       ...            ...               ...       ...
# 144957      False     False          False             False     False
# 144958      False     False           True             False     False
# 144959      False     False          False             False     False
# 144960      False     False          False             False     False
# 144961      False     False          False             False     False
#
#         followers_count  following_count  tweet_like_count  \
# ...

# %%
data.isnull().sum()
# Out:
# date_time                  0
# username                   0
# user_location          44540
# user_description       19949
# verified                   0
# followers_count            0
# following_count            0
# tweet_like_count           0
# tweet_retweet_count        0
# tweet_reply_count          0
# source                     0
# tweet_text                 0
# dtype: int64

# %%
#DATA CLEANING

# %%
data.dropna()
# Out:
#                         date_time         username  \
# 0       2022-09-09 00:19:49+00:00  Beer_Enjoyer420
# 1       2022-09-09 00:19:48+00:00    MLAIrfanSabir
# 2       2022-09-09 00:19:04+00:00         AFDJnews
# 3       2022-09-09 00:18:51+00:00       LitmusTree
# 4       2022-09-09 00:18:23+00:00      athenastits
# ...                           ...              ...
# 144956  2022-08-20 20:19:31+00:00  Jonatha67756129
# 144957  2022-08-20 20:19:10+00:00        MaryTracy
# 144959  2022-08-20 20:18:47+00:00   billyphillyboi
# 144960  2022-08-20 20:18:23+00:00      AnnaDe_2015
# 144961  2022-08-20 20:17:49+00:00   NzuchiTimesUSA
#
#                         user_location  \
# 0           District of Columbia, USA
# 1         Calgary, Treaty 7 Territory
# 2                           Australia
# 3                      Yah Dads House
# 4       they/them | 18 | uk | leftist
# ...                               ...
# 144956                         Canada
# ...

# %%
data.isnull().sum()
# Out:
# date_time                  0
# username                   0
# user_location          44540
# user_description       19949
# verified                   0
# followers_count            0
# following_count            0
# tweet_like_count           0
# tweet_retweet_count        0
# tweet_reply_count          0
# source                     0
# tweet_text                 0
# dtype: int64

# %%
data.describe()
# Out:
#        followers_count  following_count  tweet_like_count  \
# count     1.449620e+05    144962.000000     144962.000000
# mean      4.474875e+04      1735.925436         16.859922
# std       6.100741e+05      5974.358049        491.427720
# min       0.000000e+00         0.000000          0.000000
# 25%       1.020000e+02       186.000000          0.000000
# 50%       5.570000e+02       632.000000          1.000000
# 75%       2.439750e+03      1800.000000          2.000000
# max       5.422480e+07    638937.000000     105672.000000
#
#        tweet_retweet_count  tweet_reply_count
# count        144962.000000      144962.000000
# mean              4.030380           1.773865
# std             145.847155          34.595891
# min               0.000000           0.000000
# 25%               0.000000           0.000000
# 50%               0.000000           0.000000
# 75%               0.000000           1.000000
# max           44012.000000        5408.000000

# %%
len(data.tweet_like_count.unique())
# Out:
# 940

# %%
data['tweet_like_count'].unique()
# Out:
# array([     0,      1,      4,      2,      5,     11,      3,      6,
#             9,     10,     37,      8,     17,     13,      7,     16,
#            14,     25,     19,     21,     15,     36,     20,     52,
#            42,    170,     39,     43,     57,     12,     47,     33,
#            48,    356,     67,     40,     28,     24,     23,     61,
#            58,     41,     18,     46,     30,     81,    101,     22,
#          6205,    160,     70,     74,     78,     27,     94,    200,
#           404,    155,     44,    215,     84,     49,    307,     34,
#            89,     45,     75,    241,     93,     83,     66,    303,
#            31,    145,     62,    171,    348,     97,     38,     53,
#            26,    142,     29,    270,     64,     72,    121,    333,
#           153,     76,     68,     56,    178,    103,     71,     60,
#           558,    224,    239,    104,     35,    164,    174,    109,
# ...

# %%
data['tweet_like_count'].value_counts()
# Out:
# 0       72338
# 1       25283
# 2       11443
# 3        6587
# 4        4522
#         ...
# 321         1
# 744         1
# 5224        1
# 566         1
# 578         1
# Name: tweet_like_count, Length: 940, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(7,7)})
sns.displot(data.tweet_like_count,bins=3)
plt.show()

# %%
sns.boxplot(data.tweet_like_count)
# Out:
# C:\Users\shiva kishor\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tweet_like_count'>

# %%
sns.distplot(data.tweet_like_count)
# Out:
# C:\Users\shiva kishor\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tweet_like_count', ylabel='Density'>
